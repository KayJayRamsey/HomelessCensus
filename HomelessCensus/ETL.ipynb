# %%
import pandas as pd 
import csv 
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np
from us_state_abbrev import us_state_abbrev

# %%
federal_df = pd.read_csv("2007-2016-Homelessnewss-USA.csv")
state_df = pd.read_csv("Population-by-state.csv")

# %%
federal_df
# Out:
#            Year State CoC Number  \
# 0      1/1/2007    AK     AK-500
# 1      1/1/2007    AK     AK-500
# 2      1/1/2007    AK     AK-500
# 3      1/1/2007    AK     AK-500
# 4      1/1/2007    AK     AK-500
# 5      1/1/2007    AK     AK-500
# 6      1/1/2007    AK     AK-500
# 7      1/1/2007    AK     AK-500
# 8      1/1/2007    AK     AK-500
# 9      1/1/2007    AK     AK-500
# 10     1/1/2007    AK     AK-500
# 11     1/1/2007    AK     AK-500
# 12     1/1/2007    AK     AK-501
# 13     1/1/2007    AK     AK-501
# 14     1/1/2007    AK     AK-501
# 15     1/1/2007    AK     AK-501
# 16     1/1/2007    AK     AK-501
# 17     1/1/2007    AK     AK-501
# 18     1/1/2007    AK     AK-501
# 19     1/1/2007    AK     AK-501
# 20     1/1/2007    AK     AK-501
# 21     1/1/2007    AK     AK-501
# 22     1/1/2007    AK     AK-501
# 23     1/1/2007    AK     AK-501
# 24     1/1/2007    AL     AL-500
# 25     1/1/2007    AL     AL-500
# 26     1/1/2007    AL     AL-500
# ...

# %%
state_df
# Out:
#          GEO.id GEO.id2     GEO.display-label             rescen42010  \
# 0            Id     Id2             Geography  April 1, 2010 - Census
# 1   0400000US01       1               Alabama                 4779736
# 2   0400000US02       2                Alaska                  710231
# 3   0400000US04       4               Arizona                 6392017
# 4   0400000US05       5              Arkansas                 2915918
# 5   0400000US06       6            California                37253956
# 6   0400000US08       8              Colorado                 5029196
# 7   0400000US09       9           Connecticut                 3574097
# 8   0400000US10      10              Delaware                  897934
# 9   0400000US11      11  District of Columbia                  601723
# 10  0400000US12      12               Florida                18801310
# 11  0400000US13      13               Georgia                 9687653
# ...

# %%
state_df.columns = state_df.iloc[0]
state_df.head()
# Out:
# 0           Id  Id2  Geography  April 1, 2010 - Census  \
# 0           Id  Id2  Geography  April 1, 2010 - Census
# 1  0400000US01    1    Alabama                 4779736
# 2  0400000US02    2     Alaska                  710231
# 3  0400000US04    4    Arizona                 6392017
# 4  0400000US05    5   Arkansas                 2915918
#
# 0  April 1, 2010 - Estimates Base  Population Estimate (as of July 1) - 2010  \
# 0  April 1, 2010 - Estimates Base  Population Estimate (as of July 1) - 2010
# 1                         4780131                                    4785492
# 2                          710249                                     714031
# 3                         6392301                                    6408312
# 4                         2916025                                    2921995
#
# 0  Population Estimate (as of July 1) - 2011  \
# 0  Population Estimate (as of July 1) - 2011
# 1                                    4799918
# ...

# %%
state_df = state_df.reindex(state_df.index.drop(0))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-8f0c4740482d> in <module>
# ----> 1 state_df = state_df.reindex(state_df.index.drop(0))
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    4402             if errors != 'ignore':
#    4403                 raise KeyError(
# -> 4404                     '{} not found in axis'.format(labels[mask]))
#    4405             indexer = indexer[~mask]
#    4406         return self.delete(indexer)
#
# KeyError: '[0] not found in axis'

# %%
state_df.head()

# %%
state_df["Geograpy"] = state_df["Geography"].map(us_state_abbrev)

# %%
state_df = state_df.rename(columns={"Geograpy":"State", "Geography":"StateFull"})

# %%
state_df.head()
# Out:
# 0           Id Id2   StateFull April 1, 2010 - Census  \
# 1  0400000US01   1     Alabama                4779736
# 2  0400000US02   2      Alaska                 710231
# 3  0400000US04   4     Arizona                6392017
# 4  0400000US05   5    Arkansas                2915918
# 5  0400000US06   6  California               37253956
#
# 0 April 1, 2010 - Estimates Base Population Estimate (as of July 1) - 2010  \
# 1                        4780131                                   4785492
# 2                         710249                                    714031
# 3                        6392301                                   6408312
# 4                        2916025                                   2921995
# 5                       37254522                                  37332685
#
# 0 Population Estimate (as of July 1) - 2011  \
# 1                                   4799918
# 2                                    722713
# 3                                   6467163
# ...

# %%
from sqlalchemy import create_engine
from sqlconfig import password
import pymysql
pymysql.install_as_MySQLdb()

engine = create_engine(f'mysql://root:{password}@localhost:3306/homelesscensus')

# %%
state_df.to_sql("players_penalties", con=engine, if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9d5e9a2e894c> in <module>
# ----> 1 state_df.to_sql("players_penalties", con=engine, if_exists='replace')
#
# NameError: name 'state_df' is not defined

# %%
streamdf = federal_df.loc[federal_df["State"]=="AZ"]

# %%
streamdf
# Out:
#            Year State CoC Number                                   CoC Name  \
# 228    1/1/2007    AZ     AZ-500               Arizona Balance of State CoC
# 229    1/1/2007    AZ     AZ-500               Arizona Balance of State CoC
# 230    1/1/2007    AZ     AZ-500               Arizona Balance of State CoC
# 231    1/1/2007    AZ     AZ-500               Arizona Balance of State CoC
# 232    1/1/2007    AZ     AZ-500               Arizona Balance of State CoC
# 233    1/1/2007    AZ     AZ-500               Arizona Balance of State CoC
# 234    1/1/2007    AZ     AZ-500               Arizona Balance of State CoC
# 235    1/1/2007    AZ     AZ-500               Arizona Balance of State CoC
# 236    1/1/2007    AZ     AZ-500               Arizona Balance of State CoC
# 237    1/1/2007    AZ     AZ-500               Arizona Balance of State CoC
# 238    1/1/2007    AZ     AZ-500               Arizona Balance of State CoC
# ...

# %%
azbalancedf = streamdf.loc[streamdf["CoC Name"]=="Arizona Balance of State CoC"]

# %%
azbalancedf
# Out:
#            Year State CoC Number                      CoC Name  \
# 228    1/1/2007    AZ     AZ-500  Arizona Balance of State CoC
# 229    1/1/2007    AZ     AZ-500  Arizona Balance of State CoC
# 230    1/1/2007    AZ     AZ-500  Arizona Balance of State CoC
# 231    1/1/2007    AZ     AZ-500  Arizona Balance of State CoC
# 232    1/1/2007    AZ     AZ-500  Arizona Balance of State CoC
# 233    1/1/2007    AZ     AZ-500  Arizona Balance of State CoC
# 234    1/1/2007    AZ     AZ-500  Arizona Balance of State CoC
# 235    1/1/2007    AZ     AZ-500  Arizona Balance of State CoC
# 236    1/1/2007    AZ     AZ-500  Arizona Balance of State CoC
# 237    1/1/2007    AZ     AZ-500  Arizona Balance of State CoC
# 238    1/1/2007    AZ     AZ-500  Arizona Balance of State CoC
# 239    1/1/2007    AZ     AZ-500  Arizona Balance of State CoC
# 5016   1/1/2008    AZ     AZ-500  Arizona Balance of State CoC
# 5017   1/1/2008    AZ     AZ-500  Arizona Balance of State CoC
# ...

# %%
counts = [count for count in azbalancedf["Count"]]
streamfin = pd.DataFrame(columns=(["Year"],["Chronically Homeless Individuals"],["Homeless Individuals"],["Homeless People in Families"],["Sheltered Chronically Homeless Individuals"],["Sheltered Homeless"],["Sheltered Homeless Individuals"],["Sheltered Homeless People in Families"],["Total Homeless"],["Unsheltered Chronically Homeless Individuals"],["Unsheltered Homeless"],["Unsheltered Homeless Individuals"],["Unsheltered Homeless People in Families"]))

# %%
streamfin
# Out:
# Empty DataFrame
# Columns: [(Year,), (Chronically Homeless Individuals,), (Homeless Individuals,), (Homeless People in Families,), (Sheltered Chronically Homeless Individuals,), (Sheltered Homeless,), (Sheltered Homeless Individuals,), (Sheltered Homeless People in Families,), (Total Homeless,), (Unsheltered Chronically Homeless Individuals,), (Unsheltered Homeless,), (Unsheltered Homeless Individuals,), (Unsheltered Homeless People in Families,)]
# Index: []

# %%
countsrows = []
for k, v in enumerate(counts):
    countsrows.append(v)
    if k % 11 == 0 and k != 0:
        break

# %%
countsrows = []
